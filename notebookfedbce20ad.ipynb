# %% [markdown]
# <a href="https://colab.research.google.com/github/arjunchouksey123/Credit-Card-Fraud-Detection-System/blob/main/notebookfedbce20ad.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %%
from google.colab import drive
import pandas as pd

# Mount Google Drive
drive.mount('/content/drive')

# Path to the file in Google Drive
file_path = '/content/drive/My Drive/creditcard.csv'


# Read the CSV file using pandas
df = pd.read_csv(file_path)

# Display the first few rows of the dataframe
print(df.head())
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
#         V26       V27       V28  Amount  Class
# 0 -0.189115  0.133558 -0.021053  149.62      0
# 1  0.125895 -0.008983  0.014724    2.69      0
# 2 -0.139097 -0.055353 -0.059752  378.66      0
# 3 -0.221929  0.062723  0.061458  123.50      0
# 4  0.502292  0.219422  0.215153   69.99      0
#
# [5 rows x 31 columns]

# %%
# loading the dataset to a Pandas DataFrame
credit_card_data = pd.read_csv('creditcard.csv')

# %%
# first 5 rows of the dataset
credit_card_data.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
#         V26       V27       V28  Amount  Class
# 0 -0.189115  0.133558 -0.021053  149.62    0.0
# 1  0.125895 -0.008983  0.014724    2.69    0.0
# 2 -0.139097 -0.055353 -0.059752  378.66    0.0
# 3 -0.221929  0.062723  0.061458  123.50    0.0
# 4  0.502292  0.219422  0.215153   69.99    0.0
#
# [5 rows x 31 columns]

# %%
credit_card_data.tail()
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 154616  102213.0 -2.881177  3.042352 -2.037665 -2.067920  1.730641 -0.563490
# 154617  102215.0 -0.375306  0.532730  0.418723 -1.287062  2.497517  4.122187
# 154618  102227.0  2.026881 -0.097897 -0.738827  0.234993 -0.148646 -0.677590
# 154619  102229.0 -0.099578  1.072275 -1.153646  0.116668  1.755453  1.663162
# 154620  102233.0  1.502475 -0.122551 -0.002615  3.722850  0.534492  2.229096
#
#               V7        V8        V9  ...       V21       V22       V23  \
# 154616  1.903018 -0.768910  3.824377  ... -0.551010  0.444579 -0.285562
# 154617 -0.287799  1.051660  1.371592  ... -0.272822 -0.576719 -0.039171
# 154618 -0.269752 -0.135180  1.710316  ... -0.586819 -1.534632  0.521472
# 154619  0.414888  0.515391 -0.042438  ...  0.158546  0.861983 -0.007750
# 154620 -0.735919  0.566677       NaN  ...       NaN       NaN       NaN
#
#              V24       V25       V26       V27       V28  Amount  Class
# 154616 -0.282634  0.313974 -0.020883  0.758800 -0.037270    0.92    0.0
# 154617  0.603659 -0.315255 -0.548130  0.152472  0.134190    4.99    0.0
# 154618 -0.470581 -0.761147 -0.015124 -0.104300 -0.069280    6.04    0.0
# 154619 -1.217354 -0.874381  1.800225  0.014189  0.089533   24.99    0.0
# 154620       NaN       NaN       NaN       NaN       NaN     NaN    NaN
#
# [5 rows x 31 columns]

# %%
# dataset informations
credit_card_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 154621 entries, 0 to 154620
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    154621 non-null  float64
#  1   V1      154621 non-null  float64
#  2   V2      154621 non-null  float64
#  3   V3      154621 non-null  float64
#  4   V4      154621 non-null  float64
#  5   V5      154621 non-null  float64
#  6   V6      154621 non-null  float64
#  7   V7      154621 non-null  float64
#  8   V8      154621 non-null  float64
#  9   V9      154620 non-null  float64
#  10  V10     154620 non-null  float64
#  11  V11     154620 non-null  float64
#  12  V12     154620 non-null  float64
#  13  V13     154620 non-null  float64
#  14  V14     154620 non-null  float64
#  15  V15     154620 non-null  float64
#  16  V16     154620 non-null  float64
#  17  V17     154620 non-null  float64
#  18  V18     154620 non-null  float64
#  19  V19     154620 non-null  float64
#  20  V20     154620 non-null  float64
#  21  V21     154620 non-null  float64
#  22  V22     154620 non-null  float64
#  23  V23     154620 non-null  float64
#  24  V24     154620 non-null  float64
#  25  V25     154620 non-null  float64
#  26  V26     154620 non-null  float64
#  27  V27     154620 non-null  float64
#  28  V28     154620 non-null  float64
#  29  Amount  154620 non-null  float64
#  30  Class   154620 non-null  float64
# dtypes: float64(31)
# memory usage: 36.6 MB

# %%
# checking the number of missing values in each column
credit_card_data.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        1
# V10       1
# V11       1
# V12       1
# V13       1
# V14       1
# V15       1
# V16       1
# V17       1
# V18       1
# V19       1
# V20       1
# V21       1
# V22       1
# V23       1
# V24       1
# V25       1
# V26       1
# V27       1
# V28       1
# Amount    1
# Class     1
# dtype: int64

# %%
# distribution of legit transactions & fraudulent transactions
credit_card_data['Class'].value_counts()
# Out:
# 0.0    154282
# 1.0       338
# Name: Class, dtype: int64

# %% [markdown]
# This Dataset is highly unblanced
#
# 0 --> Normal Transaction
#
# 1 --> fraudulent transaction

# %%
# separating the data for analysis
legit = credit_card_data[credit_card_data.Class == 0]
fraud = credit_card_data[credit_card_data.Class == 1]

# %%
print(legit.shape)
print(fraud.shape)

# %%
# statistical measures of the data
legit.Amount.describe()
# Out:
# count    154282.000000
# mean         88.403454
# std         246.303119
# min           0.000000
# 25%           5.942500
# 50%          22.500000
# 75%          78.490000
# max       19656.530000
# Name: Amount, dtype: float64

# %%
fraud.Amount.describe()
# Out:
# count     338.000000
# mean      113.505030
# std       231.490356
# min         0.000000
# 25%         1.000000
# 50%        11.385000
# 75%       101.500000
# max      1809.680000
# Name: Amount, dtype: float64

# %%
# compare the values for both transactions
credit_card_data.groupby('Class').mean()
# Out:
#                Time        V1        V2        V3        V4        V5  \
# Class
# 0.0    55479.349237 -0.217257  0.035733  0.618457  0.126280 -0.225477
# 1.0    53350.384615 -6.175513  4.431707 -8.056080  4.862492 -4.503667
#
#              V6        V7        V8        V9  ...       V20       V21  \
# Class                                          ...
# 0.0    0.073818 -0.089808  0.047847 -0.013483  ...  0.037524 -0.039148
# 1.0   -1.478359 -7.104845  0.865868 -2.899898  ...  0.389428  0.832763
#
#             V22       V23       V24       V25       V26       V27       V28  \
# Class
# 0.0   -0.108682 -0.027470  0.011188  0.113231  0.023401  0.001220  0.002763
# 1.0   -0.060952 -0.061125 -0.061739  0.097419  0.030002  0.195944  0.057218
#
#            Amount
# Class
# 0.0     88.403454
# 1.0    113.505030
#
# [2 rows x 30 columns]

# %% [markdown]
# Under-Sampling
#
# Build a sample dataset containing similar distribution of normal transactions and Fraudulent Transactions
#
# Number of Fraudulent Transactions --> 492

# %%
legit_sample = legit.sample(n=492)

# %% [markdown]
# Concatenating two DataFrames

# %% [markdown]
# Concatenating two DataFrames

# %%
new_dataset = pd.concat([legit_sample, fraud], axis=0)

# %%
new_dataset.head()
# Out:
#            Time        V1        V2        V3        V4        V5        V6  \
# 106863  70162.0 -1.766425  1.620452  1.347082  0.728177  0.188191  1.268624
# 12783   22428.0 -0.713632  0.262699  1.062748 -2.901717  2.108954  3.606743
# 50908   44703.0  1.230690  0.266259  0.414562  0.783359 -0.647366 -1.290339
# 12208   21332.0 -1.867176 -0.525487  2.772135  3.296190  0.370889  0.617427
# 135011  81071.0 -0.510145  1.250582  0.828674 -0.185072  0.356286 -0.528608
#
#               V7        V8        V9  ...       V21       V22       V23  \
# 106863  0.325033  0.125651  1.684053  ... -0.321386  0.253341 -0.283978
# 12783  -0.156752  0.712160  2.495635  ... -0.199636 -0.208458 -0.422248
# 50908   0.006785 -0.151158  0.206718  ... -0.280581 -0.876754  0.184438
# 12208  -0.259111  0.158692  0.728401  ... -0.113549  0.452324  0.667952
# 135011  0.661055  0.010963 -0.090426  ... -0.354589 -0.896443 -0.106292
#
#              V24       V25       V26       V27       V28  Amount  Class
# 106863 -0.824598  0.255669 -0.155092  0.627488  0.096154    5.49    0.0
# 12783   0.945664  0.608921 -0.839286 -0.208737 -0.164031   11.85    0.0
# 50908   0.635982  0.128344  0.078468 -0.031303  0.031492    2.67    0.0
# 12208  -0.089935  0.327418  0.377567  0.166349 -0.134565   94.79    0.0
# 135011 -0.520452 -0.010376  0.129919  0.350705  0.148261    4.99    0.0
#
# [5 rows x 31 columns]

# %%
new_dataset.tail()
# Out:
#             Time         V1         V2         V3         V4         V5  \
# 154234  100924.0 -23.984747  16.697832 -22.209875   9.584969 -16.230439
# 154286  101051.0  -1.465316  -1.093377  -0.059768   1.064785  11.095089
# 154371  101313.0 -25.825982  19.167239 -25.390229  11.125435 -16.682644
# 154454  101597.0   0.913116   1.145381  -4.602878   2.091803  -0.473224
# 154587  102114.0 -28.255053  21.467203 -26.871339  11.737436 -17.999630
#
#               V6         V7         V8         V9  ...        V21       V22  \
# 154234  2.596333 -33.239328 -21.560039 -10.842526  ... -12.615023  5.774087
# 154286 -5.430971  -9.378025  -0.446456   1.992110  ...   1.160623 -1.259697
# 154371  3.933699 -37.060311 -28.759799 -11.126624  ... -16.922016  5.703684
# 154454 -2.085436  -1.671244   0.094397   0.337799  ...   0.401416 -0.084933
# 154587  6.065901 -41.506796 -38.987263 -13.434066  ... -21.453736  8.361985
#
#               V23       V24       V25       V26       V27       V28  Amount  \
# 154234   2.750221  0.513411 -1.608804 -0.459624 -4.626127 -0.334561    1.00
# 154286 -15.981649 -0.883670 -3.536716 -0.592965  0.675525  0.424849    0.92
# 154371   3.510019  0.054330 -0.671983 -0.209431 -4.950022 -0.448413    2.28
# 154454  -0.197684 -0.283271  0.387597 -0.553527  0.516274  0.270828  147.87
# 154587   4.909111  0.098328 -1.508739  0.008711 -5.407824 -0.183811    0.00
#
#         Class
# 154234    1.0
# 154286    1.0
# 154371    1.0
# 154454    1.0
# 154587    1.0
#
# [5 rows x 31 columns]

# %%
new_dataset['Class'].value_counts()
# Out:
# 0.0    492
# 1.0    338
# Name: Class, dtype: int64

# %%
new_dataset.groupby('Class').mean()
# Out:
#                Time        V1        V2       V3        V4        V5  \
# Class
# 0.0    55185.447154 -0.261836 -0.025633  0.54471  0.196290 -0.181107
# 1.0    53350.384615 -6.175513  4.431707 -8.05608  4.862492 -4.503667
#
#              V6        V7        V8        V9  ...       V20       V21  \
# Class                                          ...
# 0.0    0.126940 -0.014374  0.054841  0.019858  ...  0.080093 -0.062908
# 1.0   -1.478359 -7.104845  0.865868 -2.899898  ...  0.389428  0.832763
#
#             V22       V23       V24       V25       V26       V27       V28  \
# Class
# 0.0   -0.113777 -0.040556  0.044904  0.118744 -0.003754  0.004316  0.007258
# 1.0   -0.060952 -0.061125 -0.061739  0.097419  0.030002  0.195944  0.057218
#
#            Amount
# Class
# 0.0    109.212053
# 1.0    113.505030
#
# [2 rows x 30 columns]

# %% [markdown]
# Splitting the data into Features & Targets

# %%
X = new_dataset.drop(columns='Class', axis=1)
Y = new_dataset['Class']

# %%
print(X)
# Out:
#             Time         V1         V2         V3         V4         V5  \
# 106863   70162.0  -1.766425   1.620452   1.347082   0.728177   0.188191
# 12783    22428.0  -0.713632   0.262699   1.062748  -2.901717   2.108954
# 50908    44703.0   1.230690   0.266259   0.414562   0.783359  -0.647366
# 12208    21332.0  -1.867176  -0.525487   2.772135   3.296190   0.370889
# 135011   81071.0  -0.510145   1.250582   0.828674  -0.185072   0.356286
# ...          ...        ...        ...        ...        ...        ...
# 154234  100924.0 -23.984747  16.697832 -22.209875   9.584969 -16.230439
# 154286  101051.0  -1.465316  -1.093377  -0.059768   1.064785  11.095089
# 154371  101313.0 -25.825982  19.167239 -25.390229  11.125435 -16.682644
# 154454  101597.0   0.913116   1.145381  -4.602878   2.091803  -0.473224
# 154587  102114.0 -28.255053  21.467203 -26.871339  11.737436 -17.999630
#
#               V6         V7         V8         V9  ...        V20        V21  \
# 106863  1.268624   0.325033   0.125651   1.684053  ...   0.961632  -0.321386
# 12783   3.606743  -0.156752   0.712160   2.495635  ...   0.024001  -0.199636
# 50908  -1.290339   0.006785  -0.151158   0.206718  ...  -0.172728  -0.280581
# 12208   0.617427  -0.259111   0.158692   0.728401  ...   0.182777  -0.113549
# 135011 -0.528608   0.661055   0.010963  -0.090426  ...   0.241280  -0.354589
# ...          ...        ...        ...        ...  ...        ...        ...
# 154234  2.596333 -33.239328 -21.560039 -10.842526  ...   5.804551 -12.615023
# 154286 -5.430971  -9.378025  -0.446456   1.992110  ...  -1.457610   1.160623
# 154371  3.933699 -37.060311 -28.759799 -11.126624  ...   7.907378 -16.922016
# 154454 -2.085436  -1.671244   0.094397   0.337799  ...   0.508985   0.401416
# 154587  6.065901 -41.506796 -38.987263 -13.434066  ...  10.440718 -21.453736
#
#              V22        V23       V24       V25       V26       V27       V28  \
# 106863  0.253341  -0.283978 -0.824598  0.255669 -0.155092  0.627488  0.096154
# 12783  -0.208458  -0.422248  0.945664  0.608921 -0.839286 -0.208737 -0.164031
# 50908  -0.876754   0.184438  0.635982  0.128344  0.078468 -0.031303  0.031492
# 12208   0.452324   0.667952 -0.089935  0.327418  0.377567  0.166349 -0.134565
# 135011 -0.896443  -0.106292 -0.520452 -0.010376  0.129919  0.350705  0.148261
# ...          ...        ...       ...       ...       ...       ...       ...
# 154234  5.774087   2.750221  0.513411 -1.608804 -0.459624 -4.626127 -0.334561
# 154286 -1.259697 -15.981649 -0.883670 -3.536716 -0.592965  0.675525  0.424849
# 154371  5.703684   3.510019  0.054330 -0.671983 -0.209431 -4.950022 -0.448413
# 154454 -0.084933  -0.197684 -0.283271  0.387597 -0.553527  0.516274  0.270828
# 154587  8.361985   4.909111  0.098328 -1.508739  0.008711 -5.407824 -0.183811
#
#         Amount
# 106863    5.49
# 12783    11.85
# 50908     2.67
# 12208    94.79
# 135011    4.99
# ...        ...
# 154234    1.00
# 154286    0.92
# 154371    2.28
# 154454  147.87
# 154587    0.00
#
# [830 rows x 30 columns]

# %%
print(Y)
# Out:
# 106863    0.0
# 12783     0.0
# 50908     0.0
# 12208     0.0
# 135011    0.0
#          ...
# 154234    1.0
# 154286    1.0
# 154371    1.0
# 154454    1.0
# 154587    1.0
# Name: Class, Length: 830, dtype: float64

# %% [markdown]
# Split the data into Training data & Testing Data

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, stratify=Y, random_state=2)

# %%
print(X.shape, X_train.shape, X_test.shape)
# Out:
# (830, 30) (664, 30) (166, 30)

# %% [markdown]
# Model Training

# %% [markdown]
# Logistic Regression

# %%
model = LogisticRegression()

# %%
# training the Logistic Regression Model with Training Data
model.fit(X_train, Y_train)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %% [markdown]
# Model Evaluation

# %% [markdown]
# Accuracy Score

# %%
# accuracy on training data
X_train_prediction = model.predict(X_train)
training_data_accuracy = accuracy_score(X_train_prediction, Y_train)

# %%
print('Accuracy on Training data : ', training_data_accuracy)
# Out:
# Accuracy on Training data :  0.9487951807228916

# %%
# accuracy on test data
X_test_prediction = model.predict(X_test)
test_data_accuracy = accuracy_score(X_test_prediction, Y_test)

# %%
print('Accuracy score on Test Data : ', test_data_accuracy)
# Out:
# Accuracy score on Test Data :  0.9216867469879518
